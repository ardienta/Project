# %%
import pandas as pd 
import numpy as np 
import os 
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import chart_studio.plotly as py

# %%
google_playstore = pd.read_csv('googleplaystore.csv')
google_playstore = google_playstore[google_playstore['Reviews'] != '3.0M']

# %%
google_playstore.head(100)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
#     Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
google_playstore.describe()
# Out:
#             Rating
# count  9366.000000
# mean      4.191757
# std       0.515219
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
google_playstore.shape
# Out:
# (10840, 13)

# %%
google_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#google_playstore['Genres']= google_playstore['Genres'].apply(lambda x: x.split(';')[0])

# %%
plt.figure(1 , figsize = (25, 20))
sns.countplot(y = 'Genres' , data = google_playstore)
plt.show()

# %%
plt.figure(1 , figsize = (15,5))
sns.countplot(x = 'Genres' , data = google_playstore.where(google_playstore['Category']=='ART_AND_DESIGN'))
plt.show()

# %%
plt.figure(1 , figsize = (15,5))
sns.countplot(x = 'Genres' , data = google_playstore.where(google_playstore['Category']=='AUTO_AND_VEHICLES'))
plt.show()

# %%
plt.figure(1 , figsize = (15,5))
sns.countplot(x = 'Genres' , data = google_playstore.where(google_playstore['Category']=='BEAUTY'))
plt.show()

# %%
plt.figure(1 , figsize = (15,5))
sns.countplot(x = 'Genres' , data = google_playstore.where(google_playstore['Category']=='EDUCATION'))
plt.show()

# %%
plt.figure(1 , figsize = (15,5))
sns.countplot(x = 'Content Rating' , data = google_playstore)
plt.show()

# %%
google_playstore['Reviews'] = google_playstore['Reviews'].astype(str).astype(int)

# %%
import plotly.express as px
# google_playstore = px.data.gapminder().query("continent == 'Art & Design'")
google_playstore.loc[google_playstore['Reviews'] < 5000000, 'Genres'] = 'Other Genres'
fig = px.pie(google_playstore, values='Reviews', names='Genres', title='Most Favorite of Genres')
fig.show()
# Out:
# <div>                            <div id="d753066e-1d6b-4228-97d1-635bed95009d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d753066e-1d6b-4228-97d1-635bed95009d")) {                    Plotly.newPlot(                        "d753066e-1d6b-4228-97d1-635bed95009d",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Genres=%{label}<br>Reviews=%{value}<extra></extra>", "labels": ["Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "Other Genres", "O
# ...

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()
# Out:
# <div>                            <div id="5dfb32f7-c699-4cb9-9194-faff2f31d4f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dfb32f7-c699-4cb9-9194-faff2f31d4f5")) {                    Plotly.newPlot(                        "5dfb32f7-c699-4cb9-9194-faff2f31d4f5",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "country=%{label}<br>pop=%{value}<extra></extra>", "labels": ["Albania", "Austria", "Belgium", "Bosnia and Herzegovina", "Bulgaria", "Croatia", "Czech Republic", "Denmark", "Finland", "France", "Germany", "Greece", "Hungary", "Other countries", "Ireland", "Italy", "Other countries", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Serbia", "Slovak Republic", "Slovenia", "Spain", "Sweden", "
# ...
